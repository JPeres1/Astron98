# %%
# Preamble
import numpy as np
import pandas as pd

# %%
df_1 = pd.DataFrame(np.array([[4,5,2], [3,6,9], [1,2,3]]), columns= ['a', 'b', 'c'])
df_1
# Out:
#    a  b  c
# 0  4  5  2
# 1  3  6  9
# 2  1  2  3

# %%
#Using dictionary
data_dictionary = {'fruits':['apples', 'mangoes', 'strawberries', 'banana'], 'vegetables':['broccoli', 'carots', 'spinach', 'potatoes']}
df_2 = pd.DataFrame(data = data_dictionary)
df_2
# Out:
#          fruits vegetables
# 0        apples   broccoli
# 1       mangoes     carots
# 2  strawberries    spinach
# 3        banana   potatoes

# %%
df_titanic = pd.read_csv(r'C:\Users\Juanp\Astron98\Repo\pydecal_hw_dis\demos\titanic_data.csv')
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_titanic.loc[:,'Sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
df_titanic.loc[3]
# Out:
# PassengerId                                               4
# Survived                                                  1
# Pclass                                                    1
# Name           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                  female
# Age                                                    35.0
# SibSp                                                     1
# Parch                                                     0
# Ticket                                               113803
# Fare                                                   53.1
# Cabin                                                  C123
# Embarked                                                  S
# Name: 3, dtype: object

# %%
df_titanic.loc[:, 'Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df_titanic.loc[]
