# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

eagle_data= np.loadtxt(r"C:\Users\Juanp\Astron98\Repo\pydecal_hw_dis\dis\plotting\astro_image.csv")

# %%
plt.figure()
plt.imshow(eagle_data, cmap = 'twilight_shifted', vmin=50, vmax = 400,  origin = 'upper')
plt.show()

# %%
plt.figure()
plt.imshow(eagle_data, cmap = 'viridis', vmin=50, vmax = 400,  origin = 'upper')
plt.show()

# %%
baby_data= np.loadtxt(r"C:\Users\Juanp\Astron98\Repo\pydecal_hw_dis\dis\plotting\baby.csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: could not convert string to float: '"Birth'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 baby_data= np.loadtxt(r"C:\Users\Juanp\Astron98\Repo\pydecal_hw_dis\dis\plotting\baby.csv")
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\npyio.py:1356, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1353 if isinstance(delimiter, bytes):
#    1354     delimiter = delimiter.decode('latin1')
# -> 1356 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1357             converters=converters, skiplines=skiprows, usecols=usecols,
# ...

# %%
#Data
scaling_data = [10**i for i in range(5)]

# %%
#create subplots here
fig, (ax1,ax2) = plt.subplots(1,2, figsize= (12,4))

ax1.plot(scaling_data, marker = 'o')
ax1.set_title('Original Data')
ax1.set_xlabel('x')
ax1.set_ylabel('y')


ax2.plot(scaling_data)
ax2.set_title('Scaled data')
ax2.set_xlabel('x')
ax2.set_yscale('log')
ax2.set_ylabel('y')

plt.show()
