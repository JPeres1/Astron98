# %%
#preamble, import packages
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as fit

# %%
m = 0.5
b = 3 #arbitrary parameters for a linear dataset
sigma = 1 #oise
n= 20 #number of points to generate
xdata = np.arange(0,n)
ydata = m*xdata + b+ sigma*np.random.standard_normal(size=n) #generate data w spread

# %%
#check data points by looking @ graph
plt.figure(figsize =(8,6))
plt.scatter(xdata, ydata)
plt.show()

# %%
def f(x, m, b):
    return m * x + b
#y = mx+b
#y= ax^2+bx + c

p0=[0.5, 2]

parameters, covariance_matrix = fit.curve_fit(f, xdata, ydata, p0)

# %%
parameters
# Out:
# array([0.44180047, 3.53564503])

# %%
covariance_matrix
# Out:
# array([[ 0.00133367, -0.01266984],
#        [-0.01266984,  0.16470794]])

# %%
m = parameters [0]
b = parameters [1]
m_error = (covariance_matrix[0,0])**0.5
b_error = (covariance_matrix[1,1])**0.5

# %%
print('the parameters are: ', parameters)
print(' m= {0:1.5f} +\- {1:1.5f}'.format(m , m_error))
# Out:
# the parameters are:  [0.44180047 3.53564503]
#  m= 0.44180 +\- 0.03652

# %%
x=np.linspace(xdata.min(), xdata.max(), 100)
y= f(x, m, b)
plt.figure()
plt.plot(x,y)
plt.scatter(xdata, ydata)
plt.show()
